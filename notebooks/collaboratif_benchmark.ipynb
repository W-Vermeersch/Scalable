# %%
# %run ./collaborative_Final.ipynb
# Out:
# +-------+--------+-----+
# |user_id|anime_id|score|
# +-------+--------+-----+
# |     32|   34096|  8.0|
# |   1104|   34599| 10.0|
# |   1825|   28891|  7.0|
# |   3796|    2904|  9.0|
# |   9589|    4181| 10.0|
# |   9872|    2904| 10.0|
# |    554|   16664|  6.0|
# +-------+--------+-----+
# only showing top 7 rows
#
# hello
# +-------+--------+-----+
# |user_id|anime_id|score|
# +-------+--------+-----+
# |     32|   34096|  8.0|
# |   1104|   34599| 10.0|
# |   1825|   28891|  7.0|
# |   3796|    2904|  9.0|
# |   9589|    4181| 10.0|
# |   9872|    2904| 10.0|
# |    554|   16664|  6.0|
# +-------+--------+-----+
# only showing top 7 rows

# %%
scenarios = [
    (0, 0),   # nothing
    (3, 3),   # Very sparse
    (5, 10),  # Balanced
    (10, 50),  # Strict
    (10, 0),   # strict sparsed users
    (0, 10)   # strict sparsed anime
]


for min_u, min_a in scenarios:
    print(f"Testing min_user={min_u}, min_anime={min_a}")
    model = Final_train_model(min_user_reviews=min_u, min_anime_reviews=min_a)
# Out:
# Testing min_user=0, min_anime=0
# Original Row Count: 130519
# Cleaned Row Count: 130519
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 13
#      11 for min_u, min_a in scenarios:
#      12     print(f"Testing min_user={min_u}, min_anime={min_a}")
# ---> 13     model = Final_train_model(min_user_reviews=min_u, min_anime_reviews=min_a)
#
# File /tmp/ipykernel_4020/753064323.py:10, in Final_train_model(min_user_reviews, max_user_reviews, min_anime_reviews, max_anime_reviews)
#       2 final_data = clean_sparse_data(
#       3     start_data,
#       4     min_user_reviews=min_user_reviews,
#       5     max_user_reviews=max_user_reviews,
#       6     min_anime_reviews=min_anime_reviews,
#       7     max_anime_reviews=max_anime_reviews )
#       9 train_data, test_data = final_data.randomSplit([0.8, 0.2], seed=42)
# ---> 10 best_model, final_predictions  = train_and_evaluate_als(train_data, test_data)
#      11 return best_model
#
# File /tmp/ipykernel_4020/4059103642.py:4, in train_and_evaluate_als(train_data, test_data)
#       1 def train_and_evaluate_als(train_data, test_data):
# ----> 4     global_mean, user_biases, item_biases = compute_all_biases(train_data)
#       7     train_with_biases = train_data.join(user_biases, on="user_id", how="left") \
#       8                                 .join(item_biases, on="anime_id", how="left")
#      10     test_with_biases = test_data.join(user_biases, on="user_id", how="left") \
#      11                               .join(item_biases, on="anime_id", how="left")
#
# File /tmp/ipykernel_4020/1575908975.py:26, in compute_all_biases(train_data)
#      24 def compute_all_biases(train_data):
#      25     global_mean = get_global_mean(train_data)
# ---> 26     user_biases = compute_user_biases(train_data, global_mean, lambda_user)
#      27     item_biases = compute_item_biases(train_data, global_mean, lambda_item)
#      28     return global_mean, user_biases, item_biases
#
# NameError: name 'lambda_user' is not defined

# %%
model = Final_train_model(min_user_reviews=0, min_anime_reviews=0)
# Out:
# Original Row Count: 130519
# Cleaned Row Count: 130519

# %%
print("hello")

# %%
model.write().overwrite().save('/home/jovyan/work/models/user-item-best')
