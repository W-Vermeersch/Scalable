# %% [markdown]
# Preprocessing of review data

# %%
# !pip install kagglehub
# Out:
# Collecting kagglehub
#   Obtaining dependency information for kagglehub from https://files.pythonhosted.org/packages/70/14/7b1f40778a4c8930f46b5841902647396069ccaa21cb8e0779ee822ffa77/kagglehub-1.0.1-py3-none-any.whl.metadata
#   Downloading kagglehub-1.0.1-py3-none-any.whl.metadata (40 kB)
#      ---------------------------------------- 0.0/40.1 kB ? eta -:--:--
#      ---------- ----------------------------- 10.2/40.1 kB ? eta -:--:--
#      ------------------- ------------------ 20.5/40.1 kB 165.2 kB/s eta 0:00:01
#      ----------------------------- -------- 30.7/40.1 kB 217.9 kB/s eta 0:00:01
#      -------------------------------------- 40.1/40.1 kB 273.9 kB/s eta 0:00:00
# Collecting kagglesdk<1.0,>=0.1.22 (from kagglehub)
#   Obtaining dependency information for kagglesdk<1.0,>=0.1.22 from https://files.pythonhosted.org/packages/8f/4e/fead499e4e76f66203611ecee1032fc8da87f2ab59c3921c76b06334cbbf/kagglesdk-0.1.23-py3-none-any.whl.metadata
#   Downloading kagglesdk-0.1.23-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in c:\users\dell123\anaconda3\lib\site-packages (from kagglehub) (23.1)
# Requirement already satisfied: pyyaml in c:\users\dell123\anaconda3\lib\site-packages (from kagglehub) (6.0)
# Requirement already satisfied: requests in c:\users\dell123\anaconda3\lib\site-packages (from kagglehub) (2.31.0)
# Requirement already satisfied: tqdm in c:\users\dell123\anaconda3\lib\site-packages (from kagglehub) (4.65.0)
# Collecting protobuf (from kagglesdk<1.0,>=0.1.22->kagglehub)
#   Obtaining dependency information for protobuf from https://files.pythonhosted.org/packages/4d/87/cb5e585192a22b8bd457df5a2c16a75ea0db9674c3a0a39fc9347d84e075/protobuf-7.34.1-cp310-abi3-win_amd64.whl.metadata
#   Downloading protobuf-7.34.1-cp310-abi3-win_amd64.whl.metadata (595 bytes)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell123\anaconda3\lib\site-packages (from requests->kagglehub) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell123\anaconda3\lib\site-packages (from requests->kagglehub) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell123\anaconda3\lib\site-packages (from requests->kagglehub) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell123\anaconda3\lib\site-packages (from requests->kagglehub) (2023.7.22)
# Requirement already satisfied: colorama in c:\users\dell123\anaconda3\lib\site-packages (from tqdm->kagglehub) (0.4.6)
# Downloading kagglehub-1.0.1-py3-none-any.whl (70 kB)
#    ---------------------------------------- 0.0/70.6 kB ? eta -:--:--
#    ---------------------------- ----------- 51.2/70.6 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 70.6/70.6 kB 1.9 MB/s eta 0:00:00
# Downloading kagglesdk-0.1.23-py3-none-any.whl (217 kB)
#    ---------------------------------------- 0.0/217.8 kB ? eta -:--:--
#    ---------------------------------------- 217.8/217.8 kB 4.4 MB/s eta 0:00:00
# Downloading protobuf-7.34.1-cp310-abi3-win_amd64.whl (437 kB)
#    ---------------------------------------- 0.0/437.9 kB ? eta -:--:--
#    --------------------------------------  430.1/437.9 kB 13.5 MB/s eta 0:00:01
#    ---------------------------------------- 437.9/437.9 kB 9.1 MB/s eta 0:00:00
# Installing collected packages: protobuf, kagglesdk, kagglehub
# Successfully installed kagglehub-1.0.1 kagglesdk-0.1.23 protobuf-7.34.1

# %%
import pandas as pd
import kagglehub
import os
import numpy as np

# %%
# fetch data from Kaggle if not already there
path = kagglehub.dataset_download("marlesson/myanimelist-dataset-animes-profiles-reviews")
# Out:
# Downloading to C:\Users\Dell123\.cache\kagglehub\datasets\marlesson\myanimelist-dataset-animes-profiles-reviews\1.archive...
# 100%|██████████| 217M/217M [00:11<00:00, 19.5MB/s]
# Extracting files...

# %%
df = pd.read_csv(os.path.join(path, 'reviews.csv'))

# %%
df.columns
# Out:
# Index(['uid', 'profile', 'anime_uid', 'text', 'score', 'scores', 'link'], dtype='object')

# %%
#do we remove also uid?
#Note: I added profile, because uid is not the id of the user but of the review itself
df = df[['uid', 'profile', 'anime_uid', 'score']].drop_duplicates()

# %%
df.groupby(['profile', 'anime_uid']).value_counts()
# Out:
# profile           anime_uid  uid     score
# -----noname-----  2025       221727  4        1
#                   18441      210287  2        1
# ---SnowFlake---   1535       208633  6        1
# ---was-----       10110      79296   8        1
# --EYEPATCH--      35839      274580  10       1
#                                              ..
# zzz-anime         38938      309451  8        1
# zzzb              28761      272281  8        1
# zzzjynne          6675       322680  7        1
#                   18679      322740  8        1
# zzzzzzzz          9756       36814   10       1
# Name: count, Length: 130519, dtype: int64

# %%
df.to_csv("../data/preprocessed/reviewsV2.csv")
