# %% [markdown]
# Preprocessing of review data

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/reviews.csv')

# %%
df.columns
# Out:
# Index(['uid', 'profile', 'anime_uid', 'text', 'score', 'scores', 'link'], dtype='object')

# %%
df = df[['uid', 'anime_uid', 'score']].drop_duplicates()

# %%
df.groupby(['uid', 'anime_uid']).value_counts()
# Out:
# uid     anime_uid  score
# 1       1          10       1
# 9       856        8        1
# 10      263        10       1
# 11      129        9        1
# 12      210        7        1
#                            ..
# 325705  28121      9        1
# 325729  35838      9        1
# 325734  21339      7        1
# 325738  34798      10       1
# 325747  849        8        1
# Name: count, Length: 130519, dtype: int64

# %%
df.to_csv("data/preprocessed/reviews.csv")
